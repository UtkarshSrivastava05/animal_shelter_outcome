# %%
# Importing the neccessary libraries
import numpy as np
import pandas as pd
from sodapy import Socrata
from sklearn import preprocessing

# %% [markdown]
# ## Reading the dataset

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.sonomacounty.ca.gov", None)

# First 30000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("924a-vesw", limit=30000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df.head()
# Out:
#       name type               breed        color     sex   size  \
# 0  CUPCAKE  DOG  MALTESE/POODLE TOY        WHITE  Spayed    TOY
# 1      NaN  CAT         DOMESTIC SH        BLACK  Female  SMALL
# 2     LOLI  DOG        CHIHUAHUA SH  WHITE/BROWN  Spayed    TOY
# 3     LUCY  DOG    CHIHUAHUA SH/MIX  BLACK/BROWN  Spayed  SMALL
# 4      NaN  CAT             SIAMESE      SEAL PT  Female  SMALL
#
#              date_of_birth impound_number kennel_number       id  ...  \
# 0  2014-10-06T00:00:00.000     K23-045263          DA04  A328255  ...
# 1  2017-08-08T00:00:00.000     K23-045663          CS05  A419545  ...
# 2  2010-08-31T00:00:00.000     K23-045646          CS04  A267380  ...
# 3  2020-08-04T00:00:00.000     K23-045635          DS57  A419489  ...
# 4  2019-08-08T00:00:00.000     K23-045662          CS05  A419544  ...
#
#   outcome_type outcome_subtype intake_condition outcome_condition  \
# 0     ADOPTION        SCAS WEB          UNKNOWN           PENDING
# 1          NaN             NaN          UNKNOWN               NaN
# 2          NaN             NaN          UNKNOWN               NaN
# 3          NaN             NaN          UNKNOWN               NaN
# 4          NaN             NaN          UNKNOWN               NaN
#
#   intake_jurisdiction outcome_jurisdiction zip_code  \
# 0          SANTA ROSA               COUNTY    95441
# 1              COUNTY                  NaN      NaN
# 2          SANTA ROSA           SANTA ROSA    95401
# 3              COUNTY               COUNTY    95436
# 4              COUNTY                  NaN      NaN
#
#                                             location intake_total  \
# 0  {'latitude': '38.70854', 'longitude': '-122.90...            1
# 1                                                NaN            1
# 2  {'latitude': '38.44366000000008', 'longitude':...            1
# 3  {'latitude': '38.47872000000007', 'longitude':...            1
# 4                                                NaN            1
#
#   :@computed_region_dig5_f3vy
# 0                       23750
# 1                         NaN
# 2                       26075
# 3                       23747
# 4                         NaN
#
# [5 rows x 25 columns]

# %%
results_df[results_df['type']=='OTHER']['breed'].unique()
# Out:
# array(['POTBELLY PIG', 'CHICKEN', 'RABBIT SH', 'BAT', 'PEAFOWL',
#        'PARAKEET', 'MOUSE', 'GOAT', 'KOI', 'GUINEA PIG', 'PIG', 'DUCK',
#        'HAMSTER', 'REX', 'MULE', 'SHEEP', 'LOP-MINI', 'PIGEON', 'RAT',
#        'BAT/MEX FREE-TAIL', 'DUCK/MUSCOVY', 'AMERICAN', 'HARLEQUIN/MIX',
#        'LOP-MINI/MIX', 'RABBIT LH', 'LOP-ENGLISH', 'PALOMINO', 'TURKEY',
#        'LOP-HOLLAND', 'HORSE', 'COCKATIEL', 'RACCOON', 'PERUVIAN PASO',
#        'TURTLE', 'GOOSE', 'ANGORA-SATIN/MIX', 'AMERICAN/REX', 'FINCH',
#        'CHINCHILLA', 'PARROT', 'DUTCH', 'FLEMISH GIANT', 'SQUIRREL',
#        'LOP-FRENCH', 'CALIFORNIAN', 'SKUNK', 'QUARTER HORSE', 'LILAC',
#        'LOP-HOLLAND/MIX', 'OPOSSUM', 'BANTAM', 'GOAT/NUBIAN',
#        'AMERICAN SABLE/MIX', 'DOVE', 'PONY', 'LOP-AMER FUZZY',
#        'ENGLISH SPOT/MIX', 'CHECKERED GIANT', 'HIMALAYAN/MIX', 'REX/MIX',
#        'ANGORA-SATIN', 'DUCK/CAYUGA', 'GOAT/BOER', 'NETHERLND DWARF',
#        'NEW ZEALAND WHT', 'BOER', 'RHINELANDER/MIX', 'TORTOISE', 'ANGUS',
#        'CANARY', 'QUAIL', 'SILVER', 'DUTCH/MIX', 'SILVER/MIX', 'LEGHORN',
#        'ENGLISH SPOT', 'OTHER BIRD', 'HOTOT', 'FLORIDA WHITE',
#        'HOTOT/MIX', 'MACAW', 'LIZARD', 'HAVANA/MIX', 'MUSCOVY',
#        'LOP-ENGLISH/MIX', 'CHICKEN/BANTAM', 'ANGORA-ENGLISH',
#        'CALIFORNIAN/MIX', 'PAINT', 'GOAT/ALPINE', 'FERRET',
#        'SNAKE/RATTLE', 'COLD WATER', 'ARAUCANA', 'REX-MINI/MIX',
#        'HARLEQUIN', 'JERSEY/MIX', 'BARRED ROCK', 'TROPICAL',
#        'AMERICAN/MIX', 'CONURE', 'HAWK', 'DWARF HOTOT', 'DONKEY',
#        'GOAT/LA MANCHA', 'LOP-AMER FUZZY/MIX', 'HAVANA', 'SNAKE',
#        'PALOMINO/MIX', 'RABBIT LH/MIX', 'FOX', 'COCKATOO', 'JERSEY',
#        'APPALOOSA', 'LA MANCHA', 'SHETLAND', 'POLISH',
#        'NEW ZEALAND WHT/MIX', 'PYGMY', 'THOROUGHBRED', 'RHODE ISLAND',
#        'BUDGERIGAR', 'DEGU', 'LOVEBIRD', 'NETHERLND DWARF/MIX', 'SATIN',
#        'JACK', 'CHAMPGN DARGENT', 'BELGIAN HARE/MIX', 'GOAT/PYGMY',
#        'ARABIAN', 'HERON', 'ANGORA-FRENCH/FLEMISH GIANT', 'LLAMA',
#        'HORSE/PAINT', 'ALPINE/MIX'], dtype=object)

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25866 entries, 0 to 25865
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         19077 non-null  object
#  1   type                         25866 non-null  object
#  2   breed                        25866 non-null  object
#  3   color                        25866 non-null  object
#  4   sex                          25866 non-null  object
#  5   size                         25831 non-null  object
#  6   date_of_birth                19447 non-null  object
#  7   impound_number               25866 non-null  object
#  8   kennel_number                25840 non-null  object
#  9   id                           25866 non-null  object
#  10  intake_date                  25866 non-null  object
#  11  outcome_date                 25643 non-null  object
#  12  days_in_shelter              25866 non-null  object
#  13  intake_type                  25866 non-null  object
#  14  intake_subtype               25866 non-null  object
#  15  outcome_type                 25637 non-null  object
#  16  outcome_subtype              25317 non-null  object
#  17  intake_condition             25866 non-null  object
#  18  outcome_condition            25290 non-null  object
#  19  intake_jurisdiction          25866 non-null  object
#  20  outcome_jurisdiction         22144 non-null  object
#  21  zip_code                     22096 non-null  object
#  22  location                     22096 non-null  object
#  23  intake_total                 25866 non-null  object
#  24  :@computed_region_dig5_f3vy  22081 non-null  object
# dtypes: object(25)
# memory usage: 4.9+ MB

# %%
# Checking missing values
results_df.isna().sum()
# Out:
# name                           6789
# type                              0
# breed                             0
# color                             0
# sex                               0
# size                             35
# date_of_birth                  6419
# impound_number                    0
# kennel_number                    26
# id                                0
# intake_date                       0
# outcome_date                    223
# days_in_shelter                   0
# intake_type                       0
# intake_subtype                    0
# outcome_type                    229
# outcome_subtype                 549
# intake_condition                  0
# outcome_condition               576
# intake_jurisdiction               0
# outcome_jurisdiction           3722
# zip_code                       3770
# location                       3770
# intake_total                      0
# :@computed_region_dig5_f3vy    3785
# dtype: int64

# %% [markdown]
# ## Creating extra features

# %%
# Creating "has_name" boolean column from "name" column
results_df["has_name"] = results_df["name"].apply(lambda x: 0 if pd.isnull(x) else 1)
results_df.drop("name", axis=1, inplace=True)

# %%
# Calculating the "age" column

# Converting all the date columns into datetime format
results_df["date_of_birth"] = pd.to_datetime(results_df['date_of_birth'])
results_df["intake_date"] = pd.to_datetime(results_df['intake_date'])

# Calculate age by subtracting date_of_birth from intake_date
results_df['age'] = (results_df['intake_date'] - results_df['date_of_birth']).dt.days // 365

# Convert age column to bins and set NaN values to 'UNK'
age_bins = [0, 3, 6, 9, float('inf')]
age_labels = ['0-3', '3-6', '6-9', '9+']

# Create Categorical column with specified categories
results_df['age'] = pd.cut(results_df['age'], bins=age_bins, labels=age_labels, right=False)

# Set NaN values in age_bin to 'UNK'
results_df['age'] = results_df['age'].cat.add_categories(['UNK']).fillna('UNK')

results_df.head()
# Out:
#   type               breed        color     sex   size date_of_birth  \
# 0  DOG  MALTESE/POODLE TOY        WHITE  Spayed    TOY    2014-10-06
# 1  CAT         DOMESTIC SH        BLACK  Female  SMALL    2017-08-08
# 2  DOG        CHIHUAHUA SH  WHITE/BROWN  Spayed    TOY    2010-08-31
# 3  DOG    CHIHUAHUA SH/MIX  BLACK/BROWN  Spayed  SMALL    2020-08-04
# 4  CAT             SIAMESE      SEAL PT  Female  SMALL    2019-08-08
#
#   impound_number kennel_number       id intake_date  ... intake_condition  \
# 0     K23-045263          DA04  A328255  2023-07-05  ...          UNKNOWN
# 1     K23-045663          CS05  A419545  2023-08-08  ...          UNKNOWN
# 2     K23-045646          CS04  A267380  2023-08-07  ...          UNKNOWN
# 3     K23-045635          DS57  A419489  2023-08-04  ...          UNKNOWN
# 4     K23-045662          CS05  A419544  2023-08-08  ...          UNKNOWN
#
#   outcome_condition intake_jurisdiction outcome_jurisdiction zip_code  \
# 0           PENDING          SANTA ROSA               COUNTY    95441
# 1               NaN              COUNTY                  NaN      NaN
# 2               NaN          SANTA ROSA           SANTA ROSA    95401
# 3               NaN              COUNTY               COUNTY    95436
# 4               NaN              COUNTY                  NaN      NaN
#
#                                             location intake_total  \
# 0  {'latitude': '38.70854', 'longitude': '-122.90...            1
# 1                                                NaN            1
# 2  {'latitude': '38.44366000000008', 'longitude':...            1
# 3  {'latitude': '38.47872000000007', 'longitude':...            1
# 4                                                NaN            1
#
#   :@computed_region_dig5_f3vy has_name  age
# 0                       23750        1  6-9
# 1                         NaN        0  6-9
# 2                       26075        1   9+
# 3                       23747        1  3-6
# 4                         NaN        0  3-6
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Dropping unncessary records and columns

# %%
# Dropping rows with missing values in "size" and "outcome_type" columns
results_df.dropna(subset=['size'], inplace=True)
results_df.dropna(subset=['outcome_type'], inplace=True)

# %%
# Dropping the columns which are not required
results_df.drop(["date_of_birth", "impound_number", "kennel_number", "id", "outcome_subtype", "outcome_condition", 
                 "outcome_jurisdiction", "outcome_date", "zip_code", "location", ":@computed_region_dig5_f3vy"],
                axis=1, inplace=True)

# %%
# Coverting the column type for "days_in_shelter" into int format
results_df["days_in_shelter"] = results_df["days_in_shelter"].astype(int)

# %%
# Convert the "intake__date" column type to epoch time ---- WHY
results_df['intake_date'] = results_df['intake_date'].astype('int64') // 10**9

# %%
results_df.head()
# Out:
#   type               breed            color       sex   size  intake_date  \
# 0  DOG  MALTESE/POODLE TOY            WHITE    Spayed    TOY   1688515200
# 5  CAT         DOMESTIC SH  ORG TABBY/WHITE    Spayed  KITTN   1685404800
# 6  CAT         DOMESTIC SH  BRN TABBY/WHITE    Female  SMALL   1689379200
# 7  DOG          POODLE MIN            WHITE  Neutered  SMALL   1682380800
# 9  DOG                 PUG             FAWN      Male  SMALL   1691452800
#
#    days_in_shelter intake_type    intake_subtype     outcome_type  \
# 0               34       STRAY             FIELD         ADOPTION
# 5               70       STRAY  OVER THE COUNTER         ADOPTION
# 6               24       STRAY  OVER THE COUNTER         TRANSFER
# 7               85       STRAY             FIELD         ADOPTION
# 9                0       STRAY  OVER THE COUNTER  RETURN TO OWNER
#
#   intake_condition intake_jurisdiction intake_total  has_name  age
# 0          UNKNOWN          SANTA ROSA            1         1  6-9
# 5          UNKNOWN              COUNTY            1         1  0-3
# 6          UNKNOWN          SANTA ROSA            1         1   9+
# 7          UNKNOWN          SANTA ROSA            1         1  UNK
# 9          HEALTHY              COUNTY            1         1  0-3

# %% [markdown]
# ## Splitting data into predictor and target variables

# %%
X = results_df.drop("outcome_type", axis=1)
y = results_df["outcome_type"]

# %%
# Identify categorical and numerical columns
categorical_columns = X.select_dtypes(include=['object', 'category']).columns
numerical_columns = X.select_dtypes(include=['int64', 'int32']).columns

print("Categorical Columns:\n", categorical_columns)
print("\nNuerical Columns:\n", numerical_columns)
# Out:
# Categorical Columns:
#  Index(['type', 'breed', 'color', 'sex', 'size', 'intake_type',
#        'intake_subtype', 'intake_condition', 'intake_jurisdiction',
#        'intake_total', 'age'],
#       dtype='object')
#
# Nuerical Columns:
#  Index(['intake_date', 'days_in_shelter', 'has_name'], dtype='object')

# %% [markdown]
# ## Applying label encoding to all categorical columns

# %%
# label_encoder object knows 
# how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels
X_label = X[categorical_columns].apply(label_encoder.fit_transform)
# y_label = label_encoder.fit_transform(y)

# %%
X_label.head()
# Out:
#    type  breed  color  sex  size  intake_type  intake_subtype  \
# 0     1    650    293    3     5            6               3
# 5     0    409    218    3     0            6              20
# 6     0    409     94    0     4            6              20
# 7     1    805    293    2     4            6               3
# 9     1    829    153    1     4            6              20
#
#    intake_condition  intake_jurisdiction  intake_total  age
# 0                 3                   11             1    2
# 5                 3                    9             1    0
# 6                 3                   11             1    3
# 7                 3                   11             1    4
# 9                 0                    9             1    0

# %%
processed_data = X_label.join(X[numerical_columns])
processed_data = processed_data.join(y)
processed_data = processed_data.reset_index(drop = True)

processed_data.head()
# Out:
#    type  breed  color  sex  size  intake_type  intake_subtype  \
# 0     1    650    293    3     5            6               3
# 1     0    409    218    3     0            6              20
# 2     0    409     94    0     4            6              20
# 3     1    805    293    2     4            6               3
# 4     1    829    153    1     4            6              20
#
#    intake_condition  intake_jurisdiction  intake_total  age  intake_date  \
# 0                 3                   11             1    2   1688515200
# 1                 3                    9             1    0   1685404800
# 2                 3                   11             1    3   1689379200
# 3                 3                   11             1    4   1682380800
# 4                 0                    9             1    0   1691452800
#
#    days_in_shelter  has_name     outcome_type
# 0               34         1         ADOPTION
# 1               70         1         ADOPTION
# 2               24         1         TRANSFER
# 3               85         1         ADOPTION
# 4                0         1  RETURN TO OWNER

# %% [markdown]
# ## Saving the final processed data

# %%
# processed_data.to_csv("processed_data.csv", index=False)
